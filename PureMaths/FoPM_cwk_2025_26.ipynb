# %% [markdown]
# <a href="https://colab.research.google.com/github/JasonPSmith/NTUMathsTeaching/blob/main/PureMaths/FoPM_cwk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Module Code**: MATH10272
#
# **Module Title**: Foundations of Pure Mathematics
#
# **Objective**: To assess understanding of sets, relations, functions and groups
#
# **Module Leader**: Jason Smith
#
# **Format**: Jupyter Notebook
#
# **Contribution to module**: 40%
#
# **Date Set**: 28th January 2025
#
# **Deadline for Submission**: 11th February 2025, 2:30pm
#
# **Method for Submission of Jupyter Notebook**: NOW Dropbox
#
# **Deadline for Feedback**: 4th March 2025
#
# **Method of Feedback**: NOW Dropbox
#
# You can achieve a maximum of 60 marks, you need 24 marks to pass. You should attempt all questions. You should write your code and provide your answers in a Jupyter Notebook. Ensure your code is runnable and free of syntax errors. You are allowed to use built-in functions where appropriate. Submit the Jupyter Notebook (*.ipynb) to the NOW module Dropbox. This coursework is an element of assessment which means you need to pass it in order to pass the module. Plagiarism will not be tolerated, students are reminded that this is an individual assignment.

# %% [markdown]
# # **IMPORTANT:** Follow these instruction before completing the coursework.
#
# 1.   Enter your student ID below, by replacing N0123456 with your own student id.
# 2.   Enter your name below by replace Joe Bloggs with your own name.
# 3.   At the top click "Runtime" > "Run all"
#
# You do not need to click Show code, for any of the instances below. But you should rerun the code each time you open the notebook, again by selecting "Runtime" > "Run all"

# %%
student_num = "N0123456"
student_name = "Joe Bloggs"

# %%
# @title  { form-width: "1px", display-mode: "form" }
#DO NOT CHANGE THE CODE BETWEEN #++++... and #xxxx...
#++++++++++++++++++++++++++++++++++++++++++++++++++++
import matplotlib
import matplotlib.pyplot as plt

true = True
false = False
TrueOrFalse = None
ReplaceWithAnswer = None

numbers_to_use_for_individualisation = [int(j) for j in student_num[1:]]


#Q1a
def runQ1a():
    print("A = "+str(set([2*numbers_to_use_for_individualisation[i]-numbers_to_use_for_individualisation[j] for i in [2,4,5,6] for j in range(7)])))
    print("B = " + str(set([-numbers_to_use_for_individualisation[i] for i in [1,3,4,6]]+[numbers_to_use_for_individualisation[i] for i in [1,3,4,6]])))
    p = 2 if numbers_to_use_for_individualisation[-1]%2 else 3
    print("C = {x^"+str(p)+" | x is an integer}")



#Q1c
def runQ1c():
    Xstr = '[' if numbers_to_use_for_individualisation[2]%2 else '('
    Xstr+='2,'+str(numbers_to_use_for_individualisation[2]+3)+']'
    print("X = "+Xstr)
    print("Y = [" + str(-(numbers_to_use_for_individualisation[3]+1))+',2]')
    Zstr = str(-(numbers_to_use_for_individualisation[5]+1))+','+str(numbers_to_use_for_individualisation[6])
    Zstr = '['+Zstr+']' if numbers_to_use_for_individualisation[4]%2 else '('+Zstr+')'
    print("Z = " + Zstr)

def runQ2a():
        relation = "R = {(x,y)| x∈ℕ, y∈ℤ, x<"+str(numbers_to_use_for_individualisation[6]*8)+", x (mod "+str(numbers_to_use_for_individualisation[3]+2)+") ≡ "+str(numbers_to_use_for_individualisation[3])+" and |x-y|<"+str(numbers_to_use_for_individualisation[4]%3+1)+"}"
        print(relation)

    
    

def runQ2b():
    innumbers_to_use_for_individualisation = set(numbers_to_use_for_individualisation).intersection(set(range(5)))
    notnumbers_to_use_for_individualisation = set(range(5)).difference(numbers_to_use_for_individualisation)
    rels = [[(i,j) for i in innumbers_to_use_for_individualisation for j in innumbers_to_use_for_individualisation]+[(i,j) for i in notnumbers_to_use_for_individualisation for j in notnumbers_to_use_for_individualisation],set([(numbers_to_use_for_individualisation[i],numbers_to_use_for_individualisation[i+1]) for i in range(6)]+[(numbers_to_use_for_individualisation[i+1],numbers_to_use_for_individualisation[i]) for i in range(6)]).difference({(0,0)})]
    print("T = "+str(set(rels[numbers_to_use_for_individualisation[4]%2])))
    print("V = "+str(rels[(numbers_to_use_for_individualisation[4]+1)%2]))

def plotQ2b():
    fig = plt.figure()
    ax = fig.add_subplot(111)
    start = 1
    end = 20
    x = range(start,end+1)
    y = [1+(i+numbers_to_use_for_individualisation[4]) % (end-((numbers_to_use_for_individualisation[5]%2)*numbers_to_use_for_individualisation[5])) for i in x]
    plt.plot(x,y, color='k', marker='o',linestyle='None')
    plt.xlabel('x')
    plt.ylabel('f(x)')
    plt.xlim([start-1,end+1])
    plt.ylim([start-1,end+1])
    plt.xticks(range(start-1,end+1,1))
    plt.yticks(range(start-1,end+1,1))
    ax.ticklabel_format(style='plain')
    plt.grid()
    plt.show()

def runQ2c():
    print("f(x) = x+"+str(numbers_to_use_for_individualisation[-1]+1))
    print("g(x) = "+str(numbers_to_use_for_individualisation[-2]+2)+"x/"+str(numbers_to_use_for_individualisation[-3]+1))
    a1 = str(numbers_to_use_for_individualisation[-2]+2)+"(x+"+str(numbers_to_use_for_individualisation[-1]+1)+")/"+str(numbers_to_use_for_individualisation[-3]+1)
    a2 = "x-"+str(numbers_to_use_for_individualisation[-1]+1)
    a3 = "("+str(numbers_to_use_for_individualisation[-2]+2)+"x/"+str(numbers_to_use_for_individualisation[-3]+1)+")+"+str(numbers_to_use_for_individualisation[-1]+1)
    a4 = str(numbers_to_use_for_individualisation[-3]+1)+"x/"+str(numbers_to_use_for_individualisation[-2]+2)
    a5 = str(numbers_to_use_for_individualisation[-4]+1)
    a6 = str((numbers_to_use_for_individualisation[-2]+2)**2)+"x/"+str((numbers_to_use_for_individualisation[-3]+1)**2)
    a7 = str((numbers_to_use_for_individualisation[-2]+2)**2)+"x/"+str((numbers_to_use_for_individualisation[-2]+2)*(numbers_to_use_for_individualisation[-3]+1))
    fun = [a1,a2,a3,a4,a5,a6,a7]
    print("h(x) = "+fun[(numbers_to_use_for_individualisation[-1]+0)%7])
    print("p(x) = "+fun[(numbers_to_use_for_individualisation[-1]+2)%7])
    print("q(x) = "+fun[(numbers_to_use_for_individualisation[-1]+4)%7])
    print("r(x) = "+fun[(numbers_to_use_for_individualisation[-1]+6)%7])
    print("s(x) = "+fun[(numbers_to_use_for_individualisation[-1]+5)%7])
    print("t(x) = "+fun[(numbers_to_use_for_individualisation[-1]+3)%7])
    print("v(x) = "+fun[(numbers_to_use_for_individualisation[-1]+1)%7])

    
    
def op(a,b):
    G = {(numbers_to_use_for_individualisation[6]+i)%6:i for i in range(6)}
    Ginv = {i:(numbers_to_use_for_individualisation[6]+i)%6 for i in range(6)}
    return Ginv[(G[a]+G[b])%6]

def composePerm(a,b):
    if a == "e":
        return b
    if b == "e":
        return a
    if not isinstance(a,tuple) or not isinstance(b,tuple):
        print("Error: Inputs must be tuples of ints")
    n = max(max(a),max(b))
    A = {i:i for i in range(1,n+1)}
    B = {i:i for i in range(1,n+1)}
    C = {i:i for i in range(1,n+1)}
    for i in range(len(a)-1):
        A[a[i]]=a[i+1]
    A[a[-1]] = a[0]
    for i in range(len(b)-1):
        B[b[i]]=b[i+1]
    B[b[-1]] = b[0]
    for i in range(1,n+1):
        C[i] = A[B[i]]
    out = []
    notinc = set(range(1,n+1))
    inc = set()
    while len(inc) < n:
        start =  min(notinc)
        next = C[start]
        out.append([start])
        inc.add(start)
        while not start == next:
            out[-1].append(next)
            inc.add(next)
            next = C[next]
        notinc.difference_update(inc)
    return [tuple(i) for i in out if len(i)>1]


def runQ3a():
    S3 = ["e", (1,2,3), (1,3,2), (1,2),(2,3),(1,3)]
    if numbers_to_use_for_individualisation[-2] < 3:
       print("A = "+str(set(S3[:3])))
    elif numbers_to_use_for_individualisation[-2]>2 and numbers_to_use_for_individualisation[-2] < 5:
       print("A = "+str(set([S3[0]]+S3[-3:])))
    elif numbers_to_use_for_individualisation[-2]>4 and numbers_to_use_for_individualisation[-2] < 7:
       print("A = "+str(set(S3[:4])))
    else:
       print("A = "+str(set(S3[:3]+[S3[4]])))
#xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %% [markdown]
# $\mbox{}$
#
# $\mbox{}$
#
# # Question 1

# %% [markdown]
# Consider the sets $A$, $B$ and $C$ below:

# %%
# @title
runQ1a()

# %% [markdown]
# ## Part a)
#
# Find the elements of each of the following sets, you can do this by hand or use Python's set operations:
#
#
# 1.   $A \cup B$;
# 2.   $A \cap B$;
# 3.   $A \setminus B$;
# 4.   $A \cap \mathbb{N}$;
# 5.   $(A \setminus C) \cup (B \cap C)$;
# 6.   $(A \times B) \cap (B\times C)$.
#
# *6 Marks*

# %%
#Space for workings

# %%
# Enter part 1a answers here:
Q1a_answer1 = {} # Put answers between {} with values separated by commas.

Q1a_answer2 = {} # Put answers between {} with values separated by commas.

Q1a_answer3 = {} # Put answers between {} with values separated by commas.

Q1a_answer4 = {} # Put answers between {} with values separated by commas.

Q1a_answer5 = {} # Put answers between {} with values separated by commas.

Q1a_answer6 = {} # Put answers between {} with values separated by commas.

# %% [markdown]
# $\mbox{}$
#
# ## Part b)
#
# State whether each of the following is True or False:
#
#
# 1.   $1 \in A$;
# 2.   $-1 \not\in B$;
# 3.   $\emptyset\in A$;
# 4.   $\{\,|x| \,\, : \, x\in B\} \subseteq B$;
# 5.   $|A \times B| < |\mathcal{P}(A)|$;
# 6.   $C\setminus\{0\}\,\subseteq\,\mathbb{N}$.
#
# *6 Marks*

# %%
#Space for workings

# %%
# Enter part 1b answers here:
Q1b_answer1 = TrueOrFalse # Replace TrueOrFalse or with either True or False.

Q1b_answer2 = TrueOrFalse # Replace TrueOrFalse or with either True or False.

Q1b_answer3 = TrueOrFalse # Replace TrueOrFalse or with either True or False.

Q1b_answer4 = TrueOrFalse # Replace TrueOrFalse or with either True or False.

Q1b_answer5 = TrueOrFalse # Replace TrueOrFalse or with either True or False.

Q1b_answer6 = TrueOrFalse # Replace TrueOrFalse or with either True or False.

# %% [markdown]
# $\mbox{}$
#
# ## Part c)
#
# Consider the following intervals $X$, $Y$ and $Z$ of $\mathbb{R}$:

# %%
# @title
runQ1c()

# %% [markdown]
# 1.    Is $X\cap Y=\emptyset$?
# 2.    Is $X\cup Y$ an interval of $\mathbb{R}$?
# 3.    Write down the interval $X\cap Z$ in its simplest form.
# 4.    Write down the interval $Y\cup Z$ in its simplest form.
# 5.    Is $5\in Z$?
# 6.    Is $Y\subseteq Z$?
#
# *8 Marks*

# %%
#Space for workings

# %%
#Enter part 1c answers here:
Q1c_answer1 = "" #Enter Yes or No between speech marks

Q1c_answer2 = "" #Enter Yes or No between speech marks

Q1c_answer3 = "" #Enter answer between speech marks

Q1c_answer4 = "" #Enter answer between speech marks

Q1c_answer5 = "" #Enter Yes or No between speech marks

Q1c_answer6 = "" #Enter Yes or No between speech marks

# %% [markdown]
# $\mbox{}$
#
# $\mbox{}$
#
# $\mbox{}$
#
# $\mbox{}$
#
# $\mbox{}$
#
# $\mbox{}$
#
# $\mbox{}$
#
# # Question 2

# %% [markdown]
# ## Part a)
#
# Consider the relation $R$ from $\mathbb{N}$ to $\mathbb{Z}$ given by:

# %%
# @title
runQ2a()

# %% [markdown]
# 1.    What is the domain of $R$?
# 2.    What is the image of $R$?
# 3.    Is $R$ a function from $\mathbb{N}$ to $\mathbb{Z}$?
# 4.    What is $|R|$?
# 5.    Is $R$ an equivalence relation?
# 6.    What is $|\{y\,:\,5Ry\}|$?
#
# *6 Marks*

# %%
#Space for workings

# %%
#Enter part 2a answers here:
Q2a_answer1 = {} #Enter answer between {}, values separated by commas

Q2a_answer2 = {} #Enter answer between {}, values separated by commas

Q2a_answer3 = "" #Enter Yes or No between the speech marks

Q2a_answer4 = ReplaceWithAnswer

Q2a_answer5 = "" #Enter Yes or No between the speech marks

Q2a_answer6 = ReplaceWithAnswer

# %% [markdown]
# $\mbox{}$
#
# ## Part b)
# Let $N=\{x\le 20\,:\,x\in\mathbb{N}\}$ and $f$ be a function from $N$ to $N$, given by the plot below:

# %%
# @title
plotQ2b()

# %% [markdown]
# 1.    What is $f(5)$?
# 2.    Is $f$ injective?
# 3.    Is $f$ surjective?
# 4.    Is $f$ bijective?
# 5.    Does $f$ have an inverse?
# 6.    What is the image of $f$?
#
#
# *6 Marks*

# %%
#Space for workings

# %%
#Enter part 2b answers here:
Q2b_answer1 = ReplaceWithAnswer

Q2b_answer2 = "" #Enter Yes or No between the speech marks

Q2b_answer3 = "" #Enter Yes or No between the speech marks

Q2b_answer4 = "" #Enter Yes or No between the speech marks

Q2b_answer5 = "" #Enter Yes or No between the speech marks

Q2b_answer6 = {} #Enter answer between {}

# %% [markdown]
# $\mbox{}$
#
# ## Part c)
# Consider the following functions from $\mathbb{R}$ to $\mathbb{R}$:

# %%
runQ2c()

# %% [markdown]
# 1.    Which of the above functions is the inverse of $f$?
# 2.    Which of the above functions is the inverse of $g$?
# 3.    Which of the above functions is $f\circ g$?
# 4.    Which of the above functions is $g\circ g$?
# 5.    Which of the above are also functions from $\mathbb{N}$ to $\mathbb{N}$?
# 6.    Which of the above are also functions from $\mathbb{Z}$ to $\mathbb{Z}$?
# 7.    Which of the above are not injective?
# 7.    Which of the above are not surjective?
#
# *8 Marks*

# %%
#Space for workings

# %%
#Enter part 2c answers here:
Q2c_answer1 = {'f','g','h','p','q','r'}  # Delete as appropriate

Q2c_answer2 = {'f','g','h','p','q','r'}  # Delete as appropriate

Q2c_answer3 = {'f','g','h','p','q','r'}  # Delete as appropriate

Q2c_answer4 = {'f','g','h','p','q','r'}  # Delete as appropriate

Q2c_answer5 = {'f','g','h','p','q','r'}  # Delete as appropriate

Q2c_answer6 = {'f','g','h','p','q','r'}  # Delete as appropriate

Q2c_answer7 = {'f','g','h','p','q','r'}  # Delete as appropriate

Q2c_answer8 = {'f','g','h','p','q','r'}  # Delete as appropriate

# %% [markdown]
# $\mbox{}$
#
# $\mbox{}$
#
# $\mbox{}$
#
# $\mbox{}$
#
# $\mbox{}$
#
# $\mbox{}$
#
# $\mbox{}$
#
# # Question 3

# %% [markdown]
# ## Part a)

# %% [markdown]
# Consider the set A below of permutations of length $3$ (so $A\subseteq S_3$). Recall that e represents the identity permutation.
#
# For this question you can use the function composePerm(a,b) to compose permutations, for example to get the permutation (1,2,3)∘(2,3,1) use `composePerm((1,2,3),(2,3,1))`.

# %%
# @title
runQ3a()

# %% [markdown]
# 1.   Is A closed under composition? i.e., for every pair $a,b \in $A is $a\circ b \in $A
# 2.   Is A closed under inverses? i.e., for every $a \in $ A is $a^{-1} \in$ A
# 3.    Is A a subgroup of the group $S_3$ of permutations of length $3$?
#
# *9 marks*

# %%
# Space for workings
print(composePerm((1,2,3),(2,3,1))) # example use of composePerm

# %%
#AEnter part 3a answers here
Q3a_answer1 = "" #Enter Yes or No between speech marks

Q3a_answer2 = "" #Enter Yes or No between speech marks

Q3a_answer3 = "" #Enter Yes or No between speech marks

# %% [markdown]
# ## Part b)
#
# Let $G = (\{0,1,2,3,4,5\},$op$)$ be a group. You can determine the output of the binary operation a op b by typing `op(a,b)`.

# %%
# Space for workings
print(op(2,5)) # example use of op

# %% [markdown]
# 1.    What is the identity element of $G$?
# 2.    What is the order of $G$?
# 3.    What is the inverse of $5$ in $G$?
# 4.    Is $G$ Abelian?
# 5.    Does $G$ have a subgroup of order 4?
# 6.    Is $\{0,1\}$ a subgroup of $G$?
# 7.    Let $f:G\rightarrow C_4$ be the function from $G$ to the cyclic group of order $4$, given by:
# $$f =
#   \begin{pmatrix}
#     0 & 1 & 2 & 3 & 4 & 5\\
#     g & e & g^2 & g^3 & e & g^2
#   \end{pmatrix}$$
#   Is $f$ a homomorphism?
#
# *11 Marks*

# %%
# Enter part 3b answers here:
Q3b_answer1 = ReplaceWithAnswer

Q3b_answer2 = ReplaceWithAnswer

Q3b_answer3 = ReplaceWithAnswer

Q3b_answer4 = "" #Enter Yes or No between speech marks

Q3b_answer5 = "" #Enter Yes or No between speech marks

Q3b_answer6 = "" #Enter Yes or No between speech marks

Q3b_answer7 = "" #Enter Yes or No between speech marks
