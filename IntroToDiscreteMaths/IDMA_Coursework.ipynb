# %% [markdown]
# **Module Code**: MATH10541
#
# **Module Title**: Introduction to Discrete Mathematics and Applications
#
# **Objective**: To assess understanding and application of basic Python concepts
#
# **Module Leader**: Jason Smith
#
# **Format**: Jupyter Notebook
#
# **Contribution to module**: 40%
#
# **Date Set**: 29th October 2025
#
# **Deadline for Submission**: 12th November 2025, 2:30pm
#
# **Method for Submission of Jupyter Notebook**: NOW Dropbox
#
# **Deadline for Feedback**: 26th November 2025
#
# **Method of Feedback**: NOW Dropbox
#
# * You can achieve a maximum of 80 marks, you need 32 marks to pass.
# * You should attempt all questions.
# * You should write your code and provide your answers in a Jupyter Notebook.
# * **All answers should include clear comments explaining the code.**
#     - Even if your code is correct you will lose a significant amount of marks if there are no comments!
# * Ensure your code is runnable and free of syntax errors.
# * You are allowed to use built-in functions where appropriate.
# * Submit the Jupyter Notebook (*.ipynb) to the NOW module Dropbox.
#
# This coursework is an element of assessment which means you need to pass it in order to pass the module. All work will be submitted to Turnitin as a means to check for plagiarism. Plagiarism will not be tolerated, students are reminded that this is an individual assignment.

# %% [markdown]
# # IMPORTANT
#
# ### Before answering the questions you must:
# * enter your name and student ID into the cell below,
# * then click `run all` at the top of the page.
#
# #### If you do not do this your questions will not be generated correctly

# %%
# Enter your name and student ID below, between the ''
name = ''
studentID = 'N6452354'

# %%
# @title
question2 = '''Create a function called "common" that does the following:

    1) It should have 2 arguments called x and y;\n'''

a = ["    2) check if x and y are both int's, if they are not then print 'Warning: arguments of wrong type',\n\t and convert both to int;\n",
     "    2) check if x and y are both float's, if they are not then print 'Warning: arguments of wrong type',\n\t and convert both to float;\n"]

b = '    3) set x equal to '+str(3*(int(studentID[-5])+1))+'(x+'+str(5*(int(studentID[-1])+1))+'), set y equal to '+str(4*(int(studentID[-6])+1))+'y+'+str(2*(int(studentID[-7])+1))+', and then print both;\n'

c = ['    4) use a while loop to find all common divisors of x and y,\n ',
     '    4) use a while loop to find all common multiples of x and y less than 1000,\n ',]

d = ['\t and save them in a set called `output`, and print output;\n', '\t and save them in a list called `output`, and print output;\n']

e = ['    5) return the product of the numbers in `output`.\n\n\n',
     '    5) return the sum of all the numbers in `output`.\n\n\n',
     '    5) return the mean of all the numbers in `output`.\n\n\n',
     '    5) return the largest number in `output`.\n\n\n']

f = ['Call your function with argument x and y as the the ' + i +  ' of your student id,\n'
     for i in ['first and last number', 'first and second number', 'fourth and fifth number',
              'third and last number', 'second and sixth number', 'third and sixth number',
              'second and last number', 'third and sixth number', 'fifth and last number',
              'first and sixth number', 'fifth and sixth number', 'third and last number',
               'sixth and last number']]

end = '''and print the output.

Total marks: 25
'''

question2 += a[int(studentID[-7]) % 2]
question2 += b
question2 += c[int(studentID[-4]) % 2]
question2 += d[int(studentID[-3]) % 2]
question2 += e[int(studentID[-2]) % 4]
question2 += f[int(studentID[-1])]

question2 += end

def function1(x,y):
    if x % (int(studentID[1])+5) == 0 and x > 50:
        x = x - (int(studentID[-1])+1)
    if y % (int(studentID[2])+9) == 0 and y > 75:
        y = y - (int(studentID[-2])+1)
    return (x + y)**3 + y*x - (x**3 + 3*x**2*y + 4+ 3*x*y**2 + y**3) + 3 * x**2

def function2(x,y):
    if x % (int(studentID[2])+7) == 0 and x > 50:
        x = x - (int(studentID[-2])+1)
    if y % (int(studentID[1])+12) == 0 and y > 75:
        y = y - (int(studentID[-3])+1)
    return x**3 + x**y - y**3 + y**x - (x - y) * (x**2 + x*y + y**2)

def function3(x,y):
    if x % (int(studentID[2])+4) == 0 and x > 50:
        x = x - (int(studentID[-3])+1)
    if y % (int(studentID[3])+9) == 0 and y > 75:
        y = y - (int(studentID[-4])+1)
    return x**3 + 7*y**2 + y**3 + 1 - (x + y) * (x**2 - x*y + y**2) -3*x

def function4(x,y):
    if x % (int(studentID[3])+14) == 0 and x > 50:
        x = x - (int(studentID[-4])+1)
    if y % (int(studentID[4])+8) == 0 and y > 75:
        y = y - (int(studentID[-5])+1)
    return (x - y)**3 + 2 - (x**3 - 3*x*y - 3*x**2*y -x + 3*x*y**2 - y**3 -y)

def function5(x,y):
    if x % (int(studentID[4])+11) == 0 and x > 50:
        x = x - (int(studentID[-6])+1)
    if y % (int(studentID[5])+3) == 0 and y > 75:
        y = y - (int(studentID[-7])+1)
    return (x**2 - y**2) - (x - y) * (x + y) + (16/8)*x + (15//4)*y

def function6(x,y):
    if x % (int(sID[5])+15) == 0 and x > 50:
        x = x - (int(sID[-4])+1)
    if y % (int(sID[2])+13) == 0 and y > 75:
        y = y - (int(sID[-2])+1)
    return (x + y)**2 + 4 + x**2 - (x**2 + 2*y + 2*x*y + y**2)

def function7(x,y):
    if x % (int(studentID[6])+15) == 0 and x > 50:
        x = x - (int(studentID[-3])+1)
    if y % (int(studentID[2])+13) == 0 and y > 75:
        y = y - (int(studentID[-2])+1)
    return (x + y)**4 + (x*y)/2  - (x**4 + 4*x**3*y + 6*x**2*y**2 + 4*x*y**3 + y**4)

class secret_class:
    def __init__(self, sID):
        self.sID = sID
        functions = [function1, function2, function3, function4, function5, function6, function7]
        a = int(sID[-1]) % 7
        b = (a + int(sID[-2]) + 1) % 7
        c = (b + int(sID[-3]) + 1) % 7
        if b == a:
            b = (b + 1) % 7
        while c in [a,b]:
            c = (c + 1) % 7
        self.alpha = functions[a]
        self.beta = functions[b]
        self.kappa = functions[c]

secret = secret_class(studentID)

# %% [markdown]
# # Question 1

# %% [markdown]
# 1.   Create a list called `ID` which contains the numerical digits from you student ID, in the order they appear in your student ID.
#
# 2.   Convert `ID` to a set and save it as `ID_set`.
#
# 3.   Set `number_repeated_digits` equal to the absolute value of the difference in lengths between `ID` and `ID_set`, and print the value.
#
# 4.   Create an empty dictionary called `odds` and then populate it using a for loop, where the keys are the positions of odd numbers in `ID` and `odds[i]` is equal to `ID[i]`.
#
# 5.   Using exception handing (i.e. using `try` and `except`), try and set `position_3` equal to `odds[3]`, if this results in an error, then set `position_3` equal to the string "3rd number is not odd". Print `position_3` for both cases.
#
# 6.   Create a copy of `ID` and call it `ID_original`.
#
# 7.   Use a while loop to append the number `number_repeated_digits+3` onto the end of `ID` until the numbers in `ID` sum to greater than 55. Then print the length of `ID`.
#
# 8.   Set `ratio` equal to the length of `ID` divided by the length of `ID_original`. If ratio equals 1 then print "ratio equals 1", if ratio is not 1 but is an integer then print "ratio is a whole number greater than 1, otherwise print "ratio is not an integer".
#
#
# **Total marks: 25**

# %%
# Answer to Question 1

# %% [markdown]
# # Question 2

# %% [markdown]
# To view this question run the code in the cell immediately below.

# %%
print(question2)
# Out:
# Create a function called "common" that does the following:
#
#     1) It should have 2 arguments called x and y;
#     2) check if x and y are both int's, if they are not then print 'Warning: arguments of wrong type',
# 	 and convert both to int;
#     3) set x equal to 18(x+25), set y equal to 20y+14, and then print both;
#     4) use a while loop to find all common divisors of x and y,
#  	 and save them in a list called `output`, and print output;
#     5) return the sum of all the numbers in `output`.
#
#
# Call your function with argument x and y as the the second and sixth number of your student id,
# and print the output.
#
# Total marks: 25

# %%
# Answer to Question 2

# %% [markdown]
# # Question 3

# %% [markdown]
# The package `secret` has already been imported. It contains three functions, called `alpha`, `beta` and `kappa`. Each function has two arguments x and y, which must be numbers (int or float). For example, the function `alpha` could be used with `secret.alpha(1,2)`.
#
# The functions are supposed to compute one of the following polynomials, evaluated for the given x and y:
#
# *   $a(x,y)=2x + 3y$
# *   $b(x,y)=x^4 + y^5$
# *   $c(x,y)=(x \times y)/2$
# *   $d(x,y)=x^2-2y+4$
# *   $e(x,y)=7y^2-3x+1$
# *   $f(x,y)=3xy+x+y+2$
# *   $g(x,y)=yx+3x^2+4$
#
# The functions `alpha`, `beta` and `kappa` return the correct value for all pairs $x,y$ with $0\le x \le 50$ and $0\le y\le 75$.
#
# However, they return the incorrect value for at least one pair $x,y$ with $50< x \le 100$ and $75< y\le 150$.
#
# 1. For each function `alpha`, `beta` and `kappa`, determine which of the above polynomials ('a','b','c','d','e','f','g') it is implementing. You should:
#    * Use a loop to verify that the function gives the same value as the chosen polynomial for all $0\le x \le 50$ and $0\le y\le 75$.
#    * Write your answers in the cell below by creating the strings `alpha_answer`, `beta_answer`, and `kappa_answer`, and setting them equal to the letter ('a','b','c','d','e','f','g') of the selected polynomial.
#
# &nbsp;
#
# 2.
#     a. Create a set `alpha_incorrect` which contains all pairs (x,y) where `alpha` differs from the polynomial chosen for `alpha_answer` in part 1.
#
#     b. Print the string "Function alpha is incorrect for the following"
#
#     c. Using a `for` loop, for each (x,y) in `alpha_incorrect` print "Entering x and y returns p but should return q", where x, y, p and q are replaced with the actual numbers, that is, p is the value of `alpha(x,y)` and q is the  value of the chosen polynomial evaluated at (x,y).
#
#
# **Total marks: 25**

# %%
# Answers to Question 3

# %% [markdown]
# # Question 4 : Reflection

# %% [markdown]
# Write a paragraph (approximately 200 words) which reflects on what you have learnt about Python and coding thus far. Your answer should cover the folllwing points:
# 1.  What did you do to learn Python?
# 2.  How successful do you feel your approach was?
# 3.  What parts did you find most difficult?
# 4.  What might you do differently to overcome the challenges you faced?
# 5.  What will you do to continue developing your Python programming skills?
#
# **Total marks: 5**

# %%
# Answer to Question 4
